# %%
Name = input("Enter your name: ")
# Out:
# Enter your name:  sana

# %%
Age = int(input("Enter your age: "))
# Out:
# Enter your age:  20

# %%
print("Name:" , Name)
# Out:
# Name: sana

# %%
print("Age:" , Age)
# Out:
# Age: 20

# %%
Score = float(input("Enter your score"))
# Out:
# Enter your score 3.9

# %%
print("Score:" , Score)
# Out:
# Score: 3.9
