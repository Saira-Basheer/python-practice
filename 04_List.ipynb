# %%
numbers=[101,102,103,104,105]

# %%
print(numbers)
# Out:
# [101, 102, 103, 104, 105]

# %%
numbers.append(106)

# %%
print(numbers)
# Out:
# [101, 102, 103, 104, 105, 106]

# %%
numbers.insert(6,107)

# %%
print(numbers)
# Out:
# [101, 102, 103, 104, 105, 106, 107]
