# %%
salary = int(input("Enter your salary: "))

if salary < 30000:
    Tax = salary * 0.05

elif 30000 >= salary <= 70000:
    Tax = salary * 0.15

else:
    Tax = salary * 0.25
    print(" Final tax:" , Tax)
# Out:
# Enter your salary:  40000
#  Final tax: 10000.0
