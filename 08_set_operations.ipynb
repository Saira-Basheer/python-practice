# %%
A= {12,23,45,67}
B= {12,45,78,98}
print(A.intersection(B))
# Out:
# {12, 45}

# %%
A= {21,43,65,87}
B= {21,98,87,76,54}
print(A.union(B))
# Out:
# {65, 98, 43, 76, 21, 54, 87}

# %%
A= {12,23,45,67}
B= {8,9,23,45}
print(A.difference(B))
# Out:
# {67, 12}
