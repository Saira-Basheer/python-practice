# %%
numbers = [12, 7, 9, 20, 15, 18, 3, 24]
count=0
for number in numbers:
        if number%2==0:
            print(number)
            count+=1
print("total numbers" , count)
# Out:
# 12
# 20
# 18
# 24
# total numbers 4

# %%
count=1
while count<=10:
    if count%2==0:
          print(count)
    count+=1
# Out:
# 2
# 4
# 6
# 8
# 10
