# %%
def add_numbers(x,y):
    return x+y
result=add_numbers(34,56)
print(result)
# Out:
# 90

# %%
def is_even(num):
    if num%2==0:
        return "Even"
    else:
        return "Odd"
print(is_even(7))
# Out:
# Odd

# %%
def find_largest(a,b):
        return max(a,b)
  
print(find_largest(20,60))
# Out:
# 60

# %%
def square_number(z):
    return z*z

print(square_number(24))
# Out:
# 576

# %%
def Average(a,b,c):
    return (a+b+c)/3

print(Average(23,45,67))
# Out:
# 45.0

# %%
def greet(name="student"):
    return f"Hello {name}"
print(greet("name"))
# Out:
# Hello name
