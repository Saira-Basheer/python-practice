# %%
def print_numbers():
    for number in range(1,6):
            print(number)
    
print_numbers()
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def print_even():
    for number in range(1,11):
        if number%2==0:
            print(number)

print_even()
# Out:
# 2
# 4
# 6
# 8
# 10
