# %%
secret_No=17

while True:
    Guess=int(input("Enter a number:"))

    if Guess==secret_No:
        print("Congratulations")
        break
        
    elif Guess < secret_No:
        print("its less than secret,try again")

    elif Guess > secret_No:
        print("its too high , try again:")
